# %%
import numpy as np
import pandas as pd

# %%
X = pd.read_csv('train.csv')
X
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0            0   58    1                4  152          239             0
# 1            1   52    1                1  125          325             0
# 2            2   56    0                2  160          188             0
# 3            3   44    0                3  134          229             0
# 4            4   58    1                4  140          234             0
# ...        ...  ...  ...              ...  ...          ...           ...
# 629995  629995   56    0                1  110          226             0
# 629996  629996   54    1                4  128          249             1
# 629997  629997   67    1                4  130          275             0
# 629998  629998   52    1                4  140          199             0
# 629999  629999   51    0                2  130          199             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# ...

# %%
test = pd.read_csv('test.csv')
test = test.drop(['id'],axis=1)
test
# Out:
#         Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0        58    1                3  120          288             0
# 1        55    0                2  120          209             0
# 2        54    1                4  120          268             0
# 3        44    0                3  112          177             0
# 4        43    1                1  138          267             0
# ...     ...  ...              ...  ...          ...           ...
# 269995   58    1                2  120          222             0
# 269996   58    1                4  132          289             0
# 269997   63    1                3  108          201             1
# 269998   59    1                4  120          274             0
# 269999   42    1                2  120          275             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0                 2     145                1            0.8            2
# ...

# %%
Y_test = pd.read_csv('sample_submission.csv')
Y_test = Y_test['Heart Disease']
Y_test
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 269995    0
# 269996    0
# 269997    0
# 269998    0
# 269999    0
# Name: Heart Disease, Length: 270000, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()

# %%
X['Heart Disease'] = encode.fit_transform(X['Heart Disease'])
X
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0            0   58    1                4  152          239             0
# 1            1   52    1                1  125          325             0
# 2            2   56    0                2  160          188             0
# 3            3   44    0                3  134          229             0
# 4            4   58    1                4  140          234             0
# ...        ...  ...  ...              ...  ...          ...           ...
# 629995  629995   56    0                1  110          226             0
# 629996  629996   54    1                4  128          249             1
# 629997  629997   67    1                4  130          275             0
# 629998  629998   52    1                4  140          199             0
# 629999  629999   51    0                2  130          199             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# ...

# %%
X_train = X.drop(['Heart Disease','id'],axis=1)
Y_train = X['Heart Disease']

# %%
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 50, max_depth = 15, min_samples_split = 10, min_samples_leaf = 2, max_features = "sqrt" , bootstrap = True, criterion = "entropy" )
scale = StandardScaler()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=15, min_samples_leaf=2,
#                        min_samples_split=10, n_estimators=50)

# %%
Y_pred = rf.predict(test)
accuracy_score(Y_pred,Y_test)
# Out:
# 0.5587407407407408

# %%
X_process = X_train.drop(['BP','FBS over 120'],axis=1)
X_process
# Out:
#         Age  Sex  Chest pain type  Cholesterol  EKG results  Max HR  \
# 0        58    1                4          239            0     158
# 1        52    1                1          325            2     171
# 2        56    0                2          188            2     151
# 3        44    0                3          229            2     150
# 4        58    1                4          234            2     125
# ...     ...  ...              ...          ...          ...     ...
# 629995   56    0                1          226            0     132
# 629996   54    1                4          249            2     150
# 629997   67    1                4          275            0     149
# 629998   52    1                4          199            2     157
# 629999   51    0                2          199            0     168
#
#         Exercise angina  ST depression  Slope of ST  Number of vessels fluro  \
# ...

# %%
scaled_Cho = scale.fit_transform(X_process[['Cholesterol']])
scaled_HR = scale.fit_transform(X_process[['Max HR']])
scaled_Cho = np.array(scaled_Cho)
scaled_HR = np.array(scaled_HR)
scaled_Cho,scaled_HR
# Out:
# (array([[-0.17848981],
#         [ 2.37483653],
#         [-1.69267171],
#         ...,
#         [ 0.89034447],
#         [-1.36608346],
#         [-1.36608346]]),
#  array([[ 0.27119032],
#         [ 0.9513588 ],
#         [-0.09505425],
#         ...,
#         [-0.19969556],
#         [ 0.21886966],
#         [ 0.79439685]]))

# %%
X_process['Cholesterol'] = scaled_Cho
X_process['Max HR'] = scaled_HR
X_process
# Out:
#         Age  Sex  Chest pain type  Cholesterol  EKG results    Max HR  \
# 0        58    1                4    -0.178490            0  0.271190
# 1        52    1                1     2.374837            2  0.951359
# 2        56    0                2    -1.692672            2 -0.095054
# 3        44    0                3    -0.475388            2 -0.147375
# 4        58    1                4    -0.326939            2 -1.455391
# ...     ...  ...              ...          ...          ...       ...
# 629995   56    0                1    -0.564458            0 -1.089147
# 629996   54    1                4     0.118409            2 -0.147375
# 629997   67    1                4     0.890344            0 -0.199696
# 629998   52    1                4    -1.366083            2  0.218870
# 629999   51    0                2    -1.366083            0  0.794397
#
#         Exercise angina  ST depression  Slope of ST  Number of vessels fluro  \
# ...

# %%
# rf = RandomForestClassifier(n_estimators = 50, max_depth = 15, min_samples_split = 10, min_samples_leaf = 2, max_features = "sqrt" , bootstrap = True, criterion = "entropy" )
rf = RandomForestClassifier()
rf.fit(X_process,Y_train)
# Out:
# RandomForestClassifier()

# %%
test = test.drop(['BP','FBS over 120'],axis=1)

# %%
Y_pred = rf.predict(test)
Y_pred_prob = rf.predict_proba(test)

accuracy_score(Y_test,Y_pred)
# Out:
# 0.7916703703703704

# %%
Y_pred_final = Y_pred_prob[:,0]
Y_pred_final
# Out:
# array([0.48, 0.95, 0.39, ..., 0.93, 0.84, 0.84])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# Define the hyperparameter search space using distributions/ranges
param_dist = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(5, 50),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10),
    'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False],
    'criterion': ['gini', 'entropy']
}

# Initialize the Random Forest model
rf = RandomForestClassifier(random_state=42)

# Set up RandomizedSearchCV
# n_iter: number of random combinations to try
# cv: number of cross-validation folds
# n_jobs: use all available cores
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=100,
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

# Fit the random search model to the data (X_train, y_train)
random_search.fit(X_process,Y_train)

# Print the best parameters found
print("Best Parameters:", random_search.best_params_)

# %%
import cudf

# Re-initialize X_process_cudf from the unscaled X_train
X_process_cudf = cudf.DataFrame(X_train.drop(['BP','FBS over 120'],axis=1))
# Re-initialize test_cudf from the unscaled test
test_cudf = cudf.DataFrame(test)

Y_train_cudf = cudf.Series(Y_train)

print("X_process_cudf head (unscaled):")
print(X_process_cudf.head())
print("\nY_train_cudf head:")
print(Y_train_cudf.head())
print("\ntest_cudf head (unscaled):")
print(test_cudf.head())

# %%
from cuml.preprocessing import StandardScaler

# Scale 'Cholesterol' column
scaler_cholesterol = StandardScaler()
X_process_cudf['Cholesterol'] = scaler_cholesterol.fit_transform(X_process_cudf[['Cholesterol']])
test_cudf['Cholesterol'] = scaler_cholesterol.transform(test_cudf[['Cholesterol']])

# Scale 'Max HR' column
scaler_max_hr = StandardScaler()
X_process_cudf['Max HR'] = scaler_max_hr.fit_transform(X_process_cudf[['Max HR']])
test_cudf['Max HR'] = scaler_max_hr.transform(test_cudf[['Max HR']])

print("X_process_cudf head after cuML scaling:")
print(X_process_cudf.head())
print("\ntest_cudf head after cuML scaling:")
print(test_cudf.head())

# %%
Y_test = pd.read_csv('sample_submission.csv')
Y_test = Y_test['Heart Disease']
Y_pred_cuml = final_model_cuml.predict(test_cudf)

Y_test_cudf = cudf.Series(Y_test)

final_accuracy_cuml = accuracy_score(Y_test_cudf, Y_pred_cuml)

print(f"\nFinal Accuracy with cuML RandomForestClassifier: {final_accuracy_cuml:.4f}")
print(f"Best Hyperparameters found: {best_params_cuml}")
# Out:
# Final Accuracy with cuML RandomForestClassifier: 0.5603
# Best Hyperparameters found: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'entropy'}
