# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('titanicDS.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       2    male  27.0      0      0  13.0000        S  Second
# 885         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# <h2>categorical data</h2>

# %% [markdown]
# "countplot"

# %%
# sns.countplot(df['survived'])
df['survived']. value_counts().plot(kind='bar')
#learn seaborn
# Out:
# <Axes: xlabel='survived'>

# %%
df[ 'survived']. value_counts()
# Out:
# survived
# 0    547
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# "pieplot"

# %%
df['survived'].value_counts().plot(kind='pie',autopct='%f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <h2>Numerical data</h2>

# %% [markdown]
# "histogram"

# %%
plt.hist(df['age'])
# Out:
# (array([ 54.,  46., 177., 168., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df[ 'age'], bins=50)
# Out:
# (array([24.,  6., 14.,  3.,  7.,  8.,  6.,  3.,  7., 22., 13., 51., 40.,
#         27., 46., 24., 36., 47., 26., 35., 17., 34., 29., 11., 27.,  8.,
#         18.,  9., 17., 18.,  6., 17.,  6.,  9.,  7.,  2.,  7.,  4.,  7.,
#          4.,  3.,  1.,  0.,  2.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# "distplot"

# %%
sns.distplot(df['age'])
# Out:
# /var/folders/x5/vwd_1w8x5zd6tvw_jb3vgmqm0000gn/T/ipykernel_4517/3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# "boxplot"

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: >

# %%
df['age'].skew()

#if 0 : prfectly skewwed
#if +ve : positive skewwed toward right side
#if -ve : negative skewwed toward left side
# Out:
# 0.3889240246830252
