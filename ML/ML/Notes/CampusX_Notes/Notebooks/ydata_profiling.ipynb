# %%
pip install ydata-profiling

# %%
import pandas as pd

# %%
from ydata_profiling import ProfileReport

df = pd.read_csv('Desktop/Python/MACHINE LEARNING/titanicDS.csv')
profile = ProfileReport(df, title="Profiling Report")

# %%
profile
