# %%
# !pip install pandas-profiling

# %%
pip install ydata-profiling

#simple pandas profiling ma error aavtiti but aa run karyu ena pachhi eni error solve thai gai

# %%
from pandas_profiling import ProfileReport

df = pd.read_csv('titanicDS.csv')
prof = ProfileReport(df)
prof.to_file(output_file='outputreally.html')

# %%
from pandas_profiling import ProfileReport
import pandas as pd
df = pd.read_csv('cricketDS.csv')
prof = ProfileReport(df)
prof.to_file(output_file='cricketop.html')
