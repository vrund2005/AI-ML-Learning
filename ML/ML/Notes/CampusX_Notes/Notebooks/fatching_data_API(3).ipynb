# %%
import pandas as pd
import requests

# %%
res=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
res.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/avedvodAZUcwqevBfm8p4G2NziQ.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 182.493,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.705,
#    'vote_count': 26549},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
a=res.json()['results']

# %%
b=pd.DataFrame(a)

# %%
b.shape
b
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /avedvodAZUcwqevBfm8p4G2NziQ.jpg          [18, 80]     278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 5   False  /m4TUa2ciEWSlk37rOsjiSIvZDXE.jpg   [16, 10751, 14]     129
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 7   False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]     155
# 8   False  /8eihUxjQsJ7WvGySkVMC0EwbPAD.jpg      [35, 53, 18]  496243
# 9   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]     497
# 10  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [16, 10749, 18]  372058
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# ...

# %%
pd.DataFrame(a)[['title','vote_average','original_language','overview','vote_count']]

#OR ; a=(res.json()['results'])[['title','vote_average','original_language','overview','vote_count']]
# Out:
#                                             title  vote_average  \
# 0                        The Shawshank Redemption         8.705
# 1                                   The Godfather         8.691
# 2                           The Godfather Part II         8.575
# 3                                Schindler's List         8.565
# 4                                    12 Angry Men         8.543
# 5                                   Spirited Away         8.537
# 6                     Dilwale Dulhania Le Jayenge         8.536
# 7                                 The Dark Knight         8.516
# 8                                        Parasite         8.508
# 9                                  The Green Mile         8.506
# 10                                     Your Name.         8.488
# 11                                   Pulp Fiction         8.500
# 12  The Lord of the Rings: The Return of the King         8.482
# 13                                   Forrest Gump         8.475
# ...

# %%
df1=[]
for i in range(1,40):
    res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(res.json()['results'])[['title','vote_average','original_language','overview','vote_count']]
    df1.append(temp_df)

ab = pd.concat(df1,ignore_index=True)
ab
#False due to new versions ma dataframe ma append nathi thatu , list ma use kari sakay
# Out:
#                            title  vote_average original_language  \
# 0       The Shawshank Redemption         8.705                en
# 1                  The Godfather         8.691                en
# 2          The Godfather Part II         8.600                en
# 3               Schindler's List         8.565                en
# 4                   12 Angry Men         8.543                en
# ..                           ...           ...               ...
# 775   Rurouni Kenshin: The Final         7.702                ja
# 776  The Broken Circle Breakdown         7.702                nl
# 777                    Nosferatu         7.702                de
# 778   A Matter of Life and Death         7.701                en
# 779             Inherit the Wind         7.705                en
#
#                                               overview  vote_count
# 0    Imprisoned in the 1940s for the double murder ...       26555
# ...

# %%
type(ab)
# Out:
# pandas.core.frame.DataFrame

# %%
ab.to_csv('40movies.csv')

# %% [markdown]
# <h1>BELOW CODE IS FROM CHATGPT</h1>

# %%
# Initialize an empty list to store DataFrames
dfs = []

# Loop through the pages
for i in range(1, 429):
    res = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}')
    if res.status_code == 200:
        temp_df = pd.DataFrame(res.json().get('results', []))[['title','vote_average','original_language','overview','vote_count']]
        dfs.append(temp_df)
    else:
        print(f"Failed to fetch data for page {i}: Status code {res.status_code}")

# Concatenate all DataFrames in the list into a single DataFrame
if dfs:
    df = pd.concat(dfs, ignore_index=True)
    print(df)
else:
    print("No data was fetched.")
# Out:
#                                       title  vote_average original_language  \
# 0                  The Shawshank Redemption         8.705                en
# 1                             The Godfather         8.691                en
# 2                     The Godfather Part II         8.600                en
# 3                          Schindler's List         8.565                en
# 4                              12 Angry Men         8.543                en
# ...                                     ...           ...               ...
# 8555                               The Pact         5.700                en
# 8556      American Pie Presents: Beta House         5.654                en
# 8557                      The Tax Collector         5.653                en
# 8558  Legally Blonde 2: Red, White & Blonde         5.652                en
# 8559                             The Ringer         5.654                en
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv('moviess.csv')
